# %% [markdown]
# ### Clustering using scikit-learn (with pandas and matplotlib)

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import cluster
# %matplotlib inline

# %%
# Read Cities.csv into dataframe
f = open('Cities.csv')
cities = pd.read_csv(f)

# %%
# K-means clustering based on longitude-latitude
features = ['longitude', 'latitude']
kmeans = cluster.KMeans(5)
kmeans.fit(cities[features])
labels = kmeans.labels_
plt.scatter(cities['longitude'], cities['latitude'], c=labels)
plt.show()
# Try different values for K

# %%
# Now with centroids
features = ['longitude', 'latitude']
kmeans = cluster.KMeans(5)
kmeans.fit(cities[features])
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
plt.scatter(cities['longitude'], cities['latitude'], c=labels)
plt.scatter(centroids[:,0], centroids[:,1], marker='x', c='black')
plt.show()

# %%
# k-means clustering based on temperature
features = ['temperature']
kmeans = cluster.KMeans(3)
kmeans.fit(cities[features])
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
plt.scatter(cities['longitude'], cities['latitude'], c=labels, lw=0)
plt.show()
print centroids
# Out:
# [[  9.56722222]
#  [ 15.14439024]
#  [  5.7634375 ]]

# %%
# k-means clustering based on temperature
features = ['temperature']
kmeans = cluster.KMeans(3)
kmeans.fit(cities[features])
labels = kmeans.labels_

centroids = kmeans.cluster_centers_
plt.scatter(cities['longitude'], cities['latitude'], c=labels, lw=0)
plt.show()

sizes = []
for i in range(0, max(labels)+1):
    sizes.append(0)
for label in labels:
    sizes[label] +=1
print sizes
# Out:
# [66, 41, 106]

# %% [markdown]
# ### <font color="green">Your Turn: Clustering on World Cup Data</font>

# %%
# Read Players.csv into dataframe
f = open('Players.csv')
players = pd.read_csv(f)

# %%
# Create a clustering from the Players data that is meaningful and that
# you can show visually in a scatterplot. No need for centroids.

features = ['minutes', 'passes']
kmeans = cluster.KMeans(5)
kmeans.fit(players[features])
labels = kmeans.labels_
plt.scatter(players['minutes'], players['passes'], c=labels)
print labels
plt.show()
# Out:
# [0 2 0 2 0 4 0 0 2 2 2 4 2 0 0 2 2 2 4 4 3 1 3 4 3 3 3 3 1 0 2 0 0 0 3 4 3
#  2 0 4 4 4 4 2 2 0 0 4 0 4 0 4 2 0 2 2 2 0 3 4 3 0 1 0 0 1 3 3 0 1 1 3 3 4
#  4 3 0 0 2 4 0 0 4 4 4 2 4 2 0 2 0 2 0 2 0 4 3 3 2 0 0 4 0 4 3 3 2 4 0 0 2
#  4 3 0 2 3 2 0 2 2 0 0 0 2 0 0 4 4 4 0 0 2 2 2 4 3 2 4 0 4 3 3 0 4 2 0 0 3
#  4 4 3 3 4 0 4 2 0 4 0 0 4 2 0 0 4 0 2 4 2 2 0 4 0 4 2 4 1 0 0 1 0 3 0 1 0
#  1 3 3 1 1 4 1 4 0 0 1 4 1 3 1 3 4 3 2 3 4 0 1 3 4 4 2 0 4 0 4 2 4 0 0 4 0
#  4 4 0 0 2 2 2 2 4 0 2 4 2 4 4 0 0 4 4 0 4 4 0 2 4 0 2 0 0 2 2 2 2 4 0 4 2
#  0 4 4 2 0 2 0 0 2 2 0 4 4 0 4 2 4 0 4 2 4 2 4 2 2 3 3 3 3 0 3 0 3 0 3 2 3
#  3 0 3 0 0 0 0 4 0 4 0 2 3 4 4 2 4 3 3 3 3 3 3 0 0 4 0 1 0 1 1 0 2 1 1 2 3
#  1 0 1 1 3 0 2 0 0 2 2 2 2 2 2 2 2 2 2 0 0 0 0 2 2 4 4 0 0 4 0 2 2 4 4 0 2
#  2 2 2 0 2 2 2 0 0 4 0 2 2 2 2 2 3 4 2 0 2 0 4 0 3 1 1 0 1 2 4 0 2 3 0 3 4
#  0 3 3 4 0 0 3 0 3 4 3 2 0 4 4 3 2 2 0 2 2 0 4 2 4 0 4 0 4 0 4 0 2 2 4 0 2
#  2 0 3 3 0 0 2 0 0 4 3 2 0 0 0 4 3 4 2 3 2 2 2 2 2 0 2 2 2 0 2 4 0 2 0 2 2
#  4 0 0 2 4 4 2 4 2 0 2 0 0 2 0 2 0 0 2 2 3 3 2 0 0 3 0 3 0 3 0 3 0 3 3 2 1
#  0 1 1 3 4 1 0 4 0 0 0 4 1 1 1 0 2 1 1 2 0 2 0 4 0 4 0 2 2 2 2 2 0 0 0 2 2
#  0 1 3 0 0 0 0 1 3 0 2 0 4 3 1 3 1 0 3 3 3 0 3 4 3 0 3 4 3 3 3 2 4 4 0 0 3
#  3 4 0]
