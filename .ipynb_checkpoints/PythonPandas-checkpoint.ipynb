# %% [markdown]
# ### Python pandas library - storing and manipulating data in "dataframes" (tables)

# %%
import pandas as pd

# %% [markdown]
# ### Reading from CSV file into dataframe

# %%
f = open('Cities.csv')
cities = pd.read_csv(f)
cities

# Note no "print" needed
# Out:
#              city         country  latitude  longitude  temperature
# 0         Aalborg         Denmark     57.03       9.92         7.52
# 1        Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2          Abisko          Sweden     63.35      18.83         0.20
# 3           Adana          Turkey     36.99      35.32        18.67
# 4        Albacete           Spain     39.00      -1.87        12.62
# 5       Algeciras           Spain     36.13      -5.47        17.38
# 6          Amiens          France     49.90       2.30        10.17
# 7       Amsterdam     Netherlands     52.35       4.92         8.93
# 8          Ancona           Italy     43.60      13.50        13.52
# 9         Andorra         Andorra     42.50       1.52         9.60
# 10         Angers          France     47.48      -0.53        10.98
# 11         Ankara          Turkey     39.93      32.86         9.86
# 12        Antalya          Turkey     36.89      30.70        11.88
# 13           Arad         Romania     46.17      21.32         9.32
# 14         Athens          Greece     37.98      23.73        17.41
# 15       Augsburg         Germany     48.35      10.90         4.54
# 16          Bacau         Romania     46.58      26.92         7.51
# 17        Badajoz           Spain     38.88      -6.97        15.61
# 18      Baia Mare         Romania     47.66      23.58         8.87
# 19          Balti         Moldova     47.76      27.91         8.23
# 20      Barcelona           Spain     41.38       2.18        15.78
# 21           Bari           Italy     41.11      16.87        15.15
# 22          Basel     Switzerland     47.58       7.59         6.68
# 23         Batman          Turkey     37.89      41.14        14.16
# 24        Belfast  United Kingdom     54.60      -5.96         8.48
# 25       Belgrade          Serbia     44.82      20.47         9.85
# 26        Bergamo           Italy     45.70       9.67         9.12
# 27         Bergen          Norway     60.39       5.32         1.75
# 28         Berlin         Germany     52.52      13.40         8.72
# 29      Bialystok          Poland     53.15      23.17         6.07
# ..            ...             ...       ...        ...          ...
# 183         Split         Croatia     43.52      16.47        12.46
# 184  Stara Zagora        Bulgaria     42.42      25.62        10.90
# 185     Stavanger          Norway     58.97       5.68         5.53
# 186     Stockholm          Sweden     59.35      18.10         6.26
# 187          Sumy         Ukraine     50.92      34.78         6.28
# 188       Swansea  United Kingdom     51.63      -3.95         9.73
# 189        Szeged         Hungary     46.25      20.15        10.34
# 190       Tallinn         Estonia     59.43      24.73         4.82
# 191       Tampere         Finland     61.50      23.75         3.59
# 192        Tarsus          Turkey     36.92      34.88        11.21
# 193         Tartu         Estonia     58.38      26.71         4.36
# 194      Tekirdag          Turkey     40.99      27.51        13.02
# 195      Toulouse          France     43.62       1.45        10.25
# 196       Trabzon          Turkey     40.98      39.72        10.28
# 197       Trieste           Italy     45.65      13.80        11.21
# 198       Trikala          Greece     39.56      21.77        16.00
# 199     Trondheim          Norway     63.42      10.42         4.53
# 200         Turku         Finland     60.45      22.25         4.72
# 201       Uppsala          Sweden     59.86      17.64         4.17
# 202      Valencia           Spain     39.49      -0.40        16.02
# 203        Vienna         Austria     48.20      16.37         7.86
# 204          Vigo           Spain     42.22      -8.73        12.85
# 205       Vilnius       Lithuania     54.68      25.32         5.38
# 206        Warsaw          Poland     52.25      21.00         7.20
# 207       Wroclaw          Poland     51.11      17.03         7.17
# 208   Yevpatoriya         Ukraine     45.20      33.36        10.02
# 209      Zaragoza           Spain     41.65      -0.89        14.17
# 210      Zhytomyr         Ukraine     50.25      28.66         6.67
# 211     Zonguldak          Turkey     41.43      31.78        10.64
# 212        Zurich     Switzerland     47.38       8.56         6.68
#
# [213 rows x 5 columns]

# %%
# Number of rows
len(cities)

# %%
len(cities.columns)

# %%
# First few rows
cities.head(10)

# %%
# Last 20 rows
cities.tail(20)

# %%
# Statistics for numeric columns
cities.describe()

# %% [markdown]
# ### Sorting, selecting rows and columns

# %%
# Sorting by country then descending temperature
cities.sort_values(by=['country','temperature'],ascending=[True,False])

# %%
# Selecting a single column - returns a 'series'
cities.city

# Also show cities['temperature']

# %%
cities[['city']]

# %%
cities[['city', 'temperature']]

# %%
# Selecting multiple columns - returns a dataframe
cities[['city','temperature']]

# %%
cities[(cities.longitude < 0)]

# %%
# Selecting rows based on condition
cities[(cities.longitude < 0)]

# %%
# Selecting rows by number
cities[15:20]
# Show cities[:8] and cities[200:]

# %%
cities[:8]

# %%
cities[200:]

# %%
# Putting it together: selecting rows, selecting columns, sorting
# Name and longitude of all cities with latitude > 50 and temperature > 9,
# sorted by latitude
temp1 = cities[(cities.latitude > 50) & (cities.temperature > 9)]
temp2 = temp1[['city','temperature', 'latitude']]
temp2.sort_values(by='temperature')
# Show combining first two, then combining all (use \ for long lines)
# Note similar functionality to SQL

# %% [markdown]
# ### <font color="green">Your Turn</font>

# %%
# Read the Countries.csv file into a dataframe.
# Print a list of all countries that don't have coastline and
# are not in the EU, together with their highest points.
# List should be in alphabetical order.

f = open('Countries.csv')
countries = pd.read_csv(f)
countries[(countries.EU == 'no') & (countries.coastline == 'no')] \
[['country', 'highest']].sort_values(by='country')
# Out:
#                    country  highest
# 1                  Andorra     2942
# 3                  Belarus      345
# 5   Bosnia and Herzegovina     2386
# 20                  Kosovo     2656
# 22           Liechtenstein     2599
# 25               Macedonia     2764
# 26                 Moldova      430
# 33                  Serbia     2169
# 38             Switzerland     4634

# %% [markdown]
# ### Aggregation

# %%
# Minimum and maximum
print 'Minimum temperature:', min(cities['temperature'])
print 'Maximum temperature:', max(cities['temperature'])
# Out:
# Minimum temperature: -2.2
# Maximum temperature: 18.67

# %%
# Average temperature of cities in France, computed two ways
french = cities[(cities.country == 'France')]
print 'Computed as sum/count:', sum(french['temperature'])/len(french['temperature'])
print 'Computed as mean:', french['temperature'].mean()
# Out:
# Computed as sum/count: 10.1511111111
# Computed as mean: 10.1511111111

# %%
# Average temperature of cities in each country
cities.groupby('country').mean()[['temperature']]
# or with single brackets ['temperature'] or .temperature
# Also show without column selection
# Out:
#                         temperature
# country
# Albania                   15.180000
# Andorra                    9.600000
# Austria                    6.144000
# Belarus                    5.946667
# Belgium                    9.650000
# Bosnia and Herzegovina     9.600000
# Bulgaria                  10.440000
# Croatia                   10.865000
# Czech Republic             7.856667
# Denmark                    7.625000
# Estonia                    4.590000
# Finland                    3.487500
# France                    10.151111
# Germany                    7.869286
# Greece                    16.902500
# Hungary                    9.602500
# Ireland                    9.300000
# Italy                     13.474667
# Latvia                     5.270000
# Lithuania                  6.143333
# Macedonia                  9.360000
# Moldova                    8.415000
# Montenegro                 9.990000
# Netherlands                8.756667
# Norway                     3.726000
# Poland                     7.250000
# Portugal                  14.470000
# Romania                    9.224444
# Serbia                     9.850000
# Slovakia                   8.480000
# Slovenia                   9.270000
# Spain                     14.238333
# Sweden                     3.586667
# Switzerland                7.253333
# Turkey                    11.726667
# Ukraine                    7.420000
# United Kingdom             8.650000

# %%
# Average temperature of cities in each country
cities.groupby('country').mean()['temperature']
# or with single brackets ['temperature'] or .temperature
# Also show without column selection
# Out:
# country
# Albania                   15.180000
# Andorra                    9.600000
# Austria                    6.144000
# Belarus                    5.946667
# Belgium                    9.650000
# Bosnia and Herzegovina     9.600000
# Bulgaria                  10.440000
# Croatia                   10.865000
# Czech Republic             7.856667
# Denmark                    7.625000
# Estonia                    4.590000
# Finland                    3.487500
# France                    10.151111
# Germany                    7.869286
# Greece                    16.902500
# Hungary                    9.602500
# Ireland                    9.300000
# Italy                     13.474667
# Latvia                     5.270000
# Lithuania                  6.143333
# Macedonia                  9.360000
# Moldova                    8.415000
# Montenegro                 9.990000
# Netherlands                8.756667
# Norway                     3.726000
# Poland                     7.250000
# Portugal                  14.470000
# Romania                    9.224444
# Serbia                     9.850000
# Slovakia                   8.480000
# Slovenia                   9.270000
# Spain                     14.238333
# Sweden                     3.586667
# Switzerland                7.253333
# Turkey                    11.726667
# Ukraine                    7.420000
# United Kingdom             8.650000
# Name: temperature, dtype: float64

# %% [markdown]
# ### <font color="green">Your Turn</font>

# %%
# Average highest point of countries in the EU and not in the EU,
# then average highest point of countries with and without coastline
# Note: When there's more than one "query" you only see the last result.
# Try using print
print countries.groupby('EU').mean()[['highest']]
print countries.groupby('coastline').mean()[['highest']]
# Out:
#          highest
# EU
# no   2533.333333
# yes  1968.148148
#            highest
# coastline
# no         2182.50
# yes        2163.75

# %% [markdown]
# ### Joining

# %%
cityext = cities.merge(countries, on='country')
cityext
# Out:
#              city                 country  latitude  longitude  temperature  \
# 0         Aalborg                 Denmark     57.03       9.92         7.52
# 1          Odense                 Denmark     55.40      10.38         7.73
# 2        Aberdeen          United Kingdom     57.17      -2.08         8.10
# 3         Belfast          United Kingdom     54.60      -5.96         8.48
# 4      Birmingham          United Kingdom     52.47      -1.92         8.81
# 5       Blackpool          United Kingdom     53.83      -3.05         9.15
# 6     Bournemouth          United Kingdom     50.73      -1.90         9.97
# 7        Bradford          United Kingdom     53.80      -1.75         8.39
# 8       Cambridge          United Kingdom     52.20       0.12         9.25
# 9          Dundee          United Kingdom     56.47      -3.00         6.40
# 10      Edinburgh          United Kingdom     55.95      -3.22         7.43
# 11         Exeter          United Kingdom     50.70      -3.53        10.14
# 12        Glasgow          United Kingdom     55.87      -4.25         8.60
# 13      Inverness          United Kingdom     57.47      -4.23         8.00
# 14        Swansea          United Kingdom     51.63      -3.95         9.73
# 15         Abisko                  Sweden     63.35      18.83         0.20
# 16       Göteborg                  Sweden     57.75      12.00         5.76
# 17         Kiruna                  Sweden     67.85      20.22        -2.20
# 18          Malmö                  Sweden     55.58      13.03         7.33
# 19      Stockholm                  Sweden     59.35      18.10         6.26
# 20        Uppsala                  Sweden     59.86      17.64         4.17
# 21          Adana                  Turkey     36.99      35.32        18.67
# 22         Ankara                  Turkey     39.93      32.86         9.86
# 23        Antalya                  Turkey     36.89      30.70        11.88
# 24         Batman                  Turkey     37.89      41.14        14.16
# 25          Bursa                  Turkey     40.20      29.07        11.16
# 26        Denizli                  Turkey     37.77      29.08        15.02
# 27         Edirne                  Turkey     41.67      26.57        10.90
# 28       Erzincan                  Turkey     39.75      39.49         8.67
# 29        Erzurum                  Turkey     39.92      41.29         5.17
# ..            ...                     ...       ...        ...          ...
# 183        Pleven                Bulgaria     43.42      24.61        10.51
# 184       Plovdiv                Bulgaria     42.15      24.75         8.27
# 185          Ruse                Bulgaria     43.85      25.97        10.59
# 186  Stara Zagora                Bulgaria     42.42      25.62        10.90
# 187          Cork                 Ireland     51.90      -8.50         9.41
# 188        Dublin                 Ireland     53.33      -6.25         8.49
# 189        Galway                 Ireland     53.27      -9.05        10.00
# 190    Daugavpils                  Latvia     55.88      26.51         5.38
# 191          Riga                  Latvia     56.95      24.10         5.16
# 192       Elbasan                 Albania     41.12      20.08        15.18
# 193          Graz                 Austria     47.08      15.41         6.91
# 194     Innsbruck                 Austria     47.28      11.41         4.54
# 195          Linz                 Austria     48.32      14.29         6.79
# 196      Salzburg                 Austria     47.81      13.04         4.62
# 197        Vienna                 Austria     48.20      16.37         7.86
# 198      Helsinki                 Finland     60.18      24.93         4.19
# 199          Oulu                 Finland     65.00      25.47         1.45
# 200       Tampere                 Finland     61.50      23.75         3.59
# 201         Turku                 Finland     60.45      22.25         4.72
# 202        Kaunas               Lithuania     54.95      23.88         6.05
# 203      Klaipeda               Lithuania     55.72      21.12         7.00
# 204       Vilnius               Lithuania     54.68      25.32         5.38
# 205     Ljubljana                Slovenia     46.06      14.51         9.27
# 206     Podgorica              Montenegro     42.47      19.27         9.99
# 207        Rijeka                 Croatia     45.33      14.45         9.27
# 208         Split                 Croatia     43.52      16.47        12.46
# 209      Sarajevo  Bosnia and Herzegovina     43.85      13.38         9.60
# 210        Skopje               Macedonia     42.00      21.43         9.36
# 211       Tallinn                 Estonia     59.43      24.73         4.82
# 212         Tartu                 Estonia     58.38      26.71         4.36
#
#     coastline  highest   EU
# 0         yes      171  yes
# 1         yes      171  yes
# 2         yes     1344  yes
# 3         yes     1344  yes
# 4         yes     1344  yes
# 5         yes     1344  yes
# 6         yes     1344  yes
# 7         yes     1344  yes
# 8         yes     1344  yes
# 9         yes     1344  yes
# 10        yes     1344  yes
# 11        yes     1344  yes
# 12        yes     1344  yes
# 13        yes     1344  yes
# 14        yes     1344  yes
# 15        yes     2104  yes
# 16        yes     2104  yes
# 17        yes     2104  yes
# 18        yes     2104  yes
# 19        yes     2104  yes
# 20        yes     2104  yes
# 21        yes     5137   no
# 22        yes     5137   no
# 23        yes     5137   no
# 24        yes     5137   no
# 25        yes     5137   no
# 26        yes     5137   no
# 27        yes     5137   no
# 28        yes     5137   no
# 29        yes     5137   no
# ..        ...      ...  ...
# 183       yes     2925  yes
# 184       yes     2925  yes
# 185       yes     2925  yes
# 186       yes     2925  yes
# 187       yes     1041  yes
# 188       yes     1041  yes
# 189       yes     1041  yes
# 190       yes      311  yes
# 191       yes      311  yes
# 192       yes     2764   no
# 193        no     3798  yes
# 194        no     3798  yes
# 195        no     3798  yes
# 196        no     3798  yes
# 197        no     3798  yes
# 198       yes     1324  yes
# 199       yes     1324  yes
# 200       yes     1324  yes
# 201       yes     1324  yes
# 202       yes      294  yes
# 203       yes      294  yes
# 204       yes      294  yes
# 205       yes     2864  yes
# 206       yes     2534   no
# 207       yes     1831  yes
# 208       yes     1831  yes
# 209        no     2386   no
# 210        no     2764   no
# 211       yes      318  yes
# 212       yes      318  yes
#
# [213 rows x 8 columns]

# %%
# Joining is symmetric
countryext = countries.merge(cities, on='country')
countryext
# Out:
#                     country coastline  highest   EU          city  latitude  \
# 0                   Albania       yes     2764   no       Elbasan     41.12
# 1                   Andorra        no     2942   no       Andorra     42.50
# 2                   Austria        no     3798  yes          Graz     47.08
# 3                   Austria        no     3798  yes     Innsbruck     47.28
# 4                   Austria        no     3798  yes          Linz     48.32
# 5                   Austria        no     3798  yes      Salzburg     47.81
# 6                   Austria        no     3798  yes        Vienna     48.20
# 7                   Belarus        no      345   no         Brest     52.10
# 8                   Belarus        no      345   no        Hrodna     53.68
# 9                   Belarus        no      345   no         Mazyr     52.05
# 10                  Belarus        no      345   no         Minsk     53.90
# 11                  Belarus        no      345   no         Orsha     54.52
# 12                  Belarus        no      345   no         Pinsk     52.13
# 13                  Belgium       yes      694  yes        Brugge     51.22
# 14   Bosnia and Herzegovina        no     2386   no      Sarajevo     43.85
# 15                 Bulgaria       yes     2925  yes        Burgas     42.51
# 16                 Bulgaria       yes     2925  yes        Pleven     43.42
# 17                 Bulgaria       yes     2925  yes       Plovdiv     42.15
# 18                 Bulgaria       yes     2925  yes          Ruse     43.85
# 19                 Bulgaria       yes     2925  yes  Stara Zagora     42.42
# 20                  Croatia       yes     1831  yes        Rijeka     45.33
# 21                  Croatia       yes     1831  yes         Split     43.52
# 22           Czech Republic        no     1603  yes          Brno     49.20
# 23           Czech Republic        no     1603  yes       Ostrava     49.83
# 24           Czech Republic        no     1603  yes        Prague     50.08
# 25                  Denmark       yes      171  yes       Aalborg     57.03
# 26                  Denmark       yes      171  yes        Odense     55.40
# 27                  Estonia       yes      318  yes       Tallinn     59.43
# 28                  Estonia       yes      318  yes         Tartu     58.38
# 29                  Finland       yes     1324  yes      Helsinki     60.18
# ..                      ...       ...      ...  ...           ...       ...
# 183                  Turkey       yes     5137   no       Trabzon     40.98
# 184                  Turkey       yes     5137   no     Zonguldak     41.43
# 185                 Ukraine       yes     2061   no  Bila Tserkva     49.77
# 186                 Ukraine       yes     2061   no      Cherkasy     49.43
# 187                 Ukraine       yes     2061   no     Chernihiv     51.50
# 188                 Ukraine       yes     2061   no    Chernivtsi     48.31
# 189                 Ukraine       yes     2061   no      Horlivka     48.30
# 190                 Ukraine       yes     2061   no       Kherson     46.63
# 191                 Ukraine       yes     2061   no          Kiev     50.43
# 192                 Ukraine       yes     2061   no    Kremenchuk     49.08
# 193                 Ukraine       yes     2061   no    Kryvyy Rih     47.93
# 194                 Ukraine       yes     2061   no          Lvov     49.83
# 195                 Ukraine       yes     2061   no     Makiyivka     48.03
# 196                 Ukraine       yes     2061   no         Rivne     50.62
# 197                 Ukraine       yes     2061   no          Sumy     50.92
# 198                 Ukraine       yes     2061   no   Yevpatoriya     45.20
# 199                 Ukraine       yes     2061   no      Zhytomyr     50.25
# 200          United Kingdom       yes     1344  yes      Aberdeen     57.17
# 201          United Kingdom       yes     1344  yes       Belfast     54.60
# 202          United Kingdom       yes     1344  yes    Birmingham     52.47
# 203          United Kingdom       yes     1344  yes     Blackpool     53.83
# 204          United Kingdom       yes     1344  yes   Bournemouth     50.73
# 205          United Kingdom       yes     1344  yes      Bradford     53.80
# 206          United Kingdom       yes     1344  yes     Cambridge     52.20
# 207          United Kingdom       yes     1344  yes        Dundee     56.47
# 208          United Kingdom       yes     1344  yes     Edinburgh     55.95
# 209          United Kingdom       yes     1344  yes        Exeter     50.70
# 210          United Kingdom       yes     1344  yes       Glasgow     55.87
# 211          United Kingdom       yes     1344  yes     Inverness     57.47
# 212          United Kingdom       yes     1344  yes       Swansea     51.63
#
#      longitude  temperature
# 0        20.08        15.18
# 1         1.52         9.60
# 2        15.41         6.91
# 3        11.41         4.54
# 4        14.29         6.79
# 5        13.04         4.62
# 6        16.37         7.86
# 7        23.70         6.73
# 8        23.83         6.07
# 9        29.27         6.25
# 10       27.57         5.28
# 11       30.42         4.93
# 12       26.09         6.42
# 13        3.23         9.65
# 14       13.38         9.60
# 15       27.47        11.93
# 16       24.61        10.51
# 17       24.75         8.27
# 18       25.97        10.59
# 19       25.62        10.90
# 20       14.45         9.27
# 21       16.47        12.46
# 22       16.61         7.86
# 23       18.25         7.66
# 24       14.47         8.05
# 25        9.92         7.52
# 26       10.38         7.73
# 27       24.73         4.82
# 28       26.71         4.36
# 29       24.93         4.19
# ..         ...          ...
# 183      39.72        10.28
# 184      31.78        10.64
# 185      30.13         6.98
# 186      32.07         7.19
# 187      31.30         5.92
# 188      25.92         7.06
# 189      38.05         7.12
# 190      32.60         8.64
# 191      30.52         6.88
# 192      33.43         7.43
# 193      33.34         8.61
# 194      24.03         7.04
# 195      37.97         8.70
# 196      26.25         6.76
# 197      34.78         6.28
# 198      33.36        10.02
# 199      28.66         6.67
# 200      -2.08         8.10
# 201      -5.96         8.48
# 202      -1.92         8.81
# 203      -3.05         9.15
# 204      -1.90         9.97
# 205      -1.75         8.39
# 206       0.12         9.25
# 207      -3.00         6.40
# 208      -3.22         7.43
# 209      -3.53        10.14
# 210      -4.25         8.60
# 211      -4.23         8.00
# 212      -3.95         9.73
#
# [213 rows x 8 columns]

# %% [markdown]
# ### Miscellaneous features

# %%
# String operations - countries with 'ia' in their name
countries[(countries.country.str.contains('ia'))]
# Out:
#                    country coastline  highest   EU
# 0                  Albania       yes     2764   no
# 2                  Austria        no     3798  yes
# 5   Bosnia and Herzegovina        no     2386   no
# 6                 Bulgaria       yes     2925  yes
# 7                  Croatia       yes     1831  yes
# 11                 Estonia       yes      318  yes
# 21                  Latvia       yes      311  yes
# 23               Lithuania       yes      294  yes
# 25               Macedonia        no     2764   no
# 32                 Romania       yes     2544  yes
# 33                  Serbia        no     2169   no
# 34                Slovakia        no     2655  yes
# 35                Slovenia       yes     2864  yes

# %%
# Plotting
import matplotlib
# %matplotlib inline
cities.plot.scatter(x='latitude', y='temperature')

# %%
# Add temp-fahrenheit column
cities['temp-fahrenheit'] = (cities.temperature * 9/5) + 32
cities
# Out:
#              city         country  latitude  longitude  temperature  \
# 0         Aalborg         Denmark     57.03       9.92         7.52
# 1        Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2          Abisko          Sweden     63.35      18.83         0.20
# 3           Adana          Turkey     36.99      35.32        18.67
# 4        Albacete           Spain     39.00      -1.87        12.62
# 5       Algeciras           Spain     36.13      -5.47        17.38
# 6          Amiens          France     49.90       2.30        10.17
# 7       Amsterdam     Netherlands     52.35       4.92         8.93
# 8          Ancona           Italy     43.60      13.50        13.52
# 9         Andorra         Andorra     42.50       1.52         9.60
# 10         Angers          France     47.48      -0.53        10.98
# 11         Ankara          Turkey     39.93      32.86         9.86
# 12        Antalya          Turkey     36.89      30.70        11.88
# 13           Arad         Romania     46.17      21.32         9.32
# 14         Athens          Greece     37.98      23.73        17.41
# 15       Augsburg         Germany     48.35      10.90         4.54
# 16          Bacau         Romania     46.58      26.92         7.51
# 17        Badajoz           Spain     38.88      -6.97        15.61
# 18      Baia Mare         Romania     47.66      23.58         8.87
# 19          Balti         Moldova     47.76      27.91         8.23
# 20      Barcelona           Spain     41.38       2.18        15.78
# 21           Bari           Italy     41.11      16.87        15.15
# 22          Basel     Switzerland     47.58       7.59         6.68
# 23         Batman          Turkey     37.89      41.14        14.16
# 24        Belfast  United Kingdom     54.60      -5.96         8.48
# 25       Belgrade          Serbia     44.82      20.47         9.85
# 26        Bergamo           Italy     45.70       9.67         9.12
# 27         Bergen          Norway     60.39       5.32         1.75
# 28         Berlin         Germany     52.52      13.40         8.72
# 29      Bialystok          Poland     53.15      23.17         6.07
# ..            ...             ...       ...        ...          ...
# 183         Split         Croatia     43.52      16.47        12.46
# 184  Stara Zagora        Bulgaria     42.42      25.62        10.90
# 185     Stavanger          Norway     58.97       5.68         5.53
# 186     Stockholm          Sweden     59.35      18.10         6.26
# 187          Sumy         Ukraine     50.92      34.78         6.28
# 188       Swansea  United Kingdom     51.63      -3.95         9.73
# 189        Szeged         Hungary     46.25      20.15        10.34
# 190       Tallinn         Estonia     59.43      24.73         4.82
# 191       Tampere         Finland     61.50      23.75         3.59
# 192        Tarsus          Turkey     36.92      34.88        11.21
# 193         Tartu         Estonia     58.38      26.71         4.36
# 194      Tekirdag          Turkey     40.99      27.51        13.02
# 195      Toulouse          France     43.62       1.45        10.25
# 196       Trabzon          Turkey     40.98      39.72        10.28
# 197       Trieste           Italy     45.65      13.80        11.21
# 198       Trikala          Greece     39.56      21.77        16.00
# 199     Trondheim          Norway     63.42      10.42         4.53
# 200         Turku         Finland     60.45      22.25         4.72
# 201       Uppsala          Sweden     59.86      17.64         4.17
# 202      Valencia           Spain     39.49      -0.40        16.02
# 203        Vienna         Austria     48.20      16.37         7.86
# 204          Vigo           Spain     42.22      -8.73        12.85
# 205       Vilnius       Lithuania     54.68      25.32         5.38
# 206        Warsaw          Poland     52.25      21.00         7.20
# 207       Wroclaw          Poland     51.11      17.03         7.17
# 208   Yevpatoriya         Ukraine     45.20      33.36        10.02
# 209      Zaragoza           Spain     41.65      -0.89        14.17
# 210      Zhytomyr         Ukraine     50.25      28.66         6.67
# 211     Zonguldak          Turkey     41.43      31.78        10.64
# 212        Zurich     Switzerland     47.38       8.56         6.68
#
#      temp-fahrenheit
# 0             45.536
# 1             46.580
# 2             32.360
# 3             65.606
# 4             54.716
# 5             63.284
# 6             50.306
# 7             48.074
# 8             56.336
# 9             49.280
# 10            51.764
# 11            49.748
# 12            53.384
# 13            48.776
# 14            63.338
# 15            40.172
# 16            45.518
# 17            60.098
# 18            47.966
# 19            46.814
# 20            60.404
# 21            59.270
# 22            44.024
# 23            57.488
# 24            47.264
# 25            49.730
# 26            48.416
# 27            35.150
# 28            47.696
# 29            42.926
# ..               ...
# 183           54.428
# 184           51.620
# 185           41.954
# 186           43.268
# 187           43.304
# 188           49.514
# 189           50.612
# 190           40.676
# 191           38.462
# 192           52.178
# 193           39.848
# 194           55.436
# 195           50.450
# 196           50.504
# 197           52.178
# 198           60.800
# 199           40.154
# 200           40.496
# 201           39.506
# 202           60.836
# 203           46.148
# 204           55.130
# 205           41.684
# 206           44.960
# 207           44.906
# 208           50.036
# 209           57.506
# 210           44.006
# 211           51.152
# 212           44.024
#
# [213 rows x 6 columns]

# %% [markdown]
# ### <font color="green">Your Turn: World Cup data</font>

# %%
# Read the Players and Teams data into dataframes
f = open('Players.csv')
players = pd.read_csv(f)
f = open('Teams.csv')
teams = pd.read_csv(f)

# %%
# What player on a team with “ia” in the team name played less than
# 200 minutes and made more than 100 passes? Print the player surname.
surname = []
players[(players.team.str.contains('ia')) & (players.minutes > 200) & (players.passes > 100)][['surname']]
#for player in players:
#    player['team']
#    if str(player['team']).find("ia") != -1:
  #      if float(player['minutes']) < 200 and float(player['passes']) > 100:
    #        surname.append(player['surname'])
# Out:
#            surname
# 1          Belhadj
# 9            Kadir
# 10           Lacen
# 16           Yebda
# 43          Culina
# 52           Neill
# 55          Valeri
# 56       Wilkshire
# 357          Etuhu
# 364          Odiah
# 426       Ivanovic
# 439      Stankovic
# 443          Vidic
# 446         Durica
# 447         Hamsik
# 460         Skrtel
# 462          Strba
# 463         Vittek
# 471          Jokic
# 474          Koren
# 479  Radosavljevic
# 480          Suler

# %%
# What is the average number of passes made by defenders? By forwards?

# %%
# Which team has the highest ratio of goalsFor to goalsAgainst?
# Print the team name only.
# Hint: Add a "ratio" column to the teams dataframe, then sort,
# then use head(1) or tail(1) depending how you sorted

# %%
# How many players on a team with ranking <10 played more than 350 minutes?
# Reminder: len() gives number of rows i a dataframe

# %%
# BONUS!
# Write a loop that interactively asks the user to enter a team name.
# If the team exists, list all of the players on that team
# (with all of their information), sorted by descending minutes played.
# If the team doesn't exist, print "Team not in 2010 World Cup".
# If 'quit' is entered, terminate the loop.
# Reminder: To read a string from the user instead of a number, use
# raw_input() instead of input()
# Note: To test if a value v is (not) in a column c of a dataframe D,
# use "v (not) in D['c'].values"
